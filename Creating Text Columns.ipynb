# %%
import pandas as pd
import numpy as np

# %%
groceries = pd.read_excel('Groceries.xlsx')
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment
# 0 2023-06-12 15:35:00              2023-06-15
# 1 2023-06-12 18:30:00              2023-06-15
# 2 2023-06-12 17:22:00              2023-06-15
# 3 2023-06-12 16:29:00              2023-06-15
# 4 2023-06-12 18:10:00              2023-06-15

# %%
# remove P from Product_ID
groceries['Product_ID_Num'] = groceries.Product_ID.str[1:]
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment Product_ID_Num
# 0 2023-06-12 15:35:00              2023-06-15         100010
# 1 2023-06-12 18:30:00              2023-06-15         100011
# 2 2023-06-12 17:22:00              2023-06-15         100012
# 3 2023-06-12 16:29:00              2023-06-15         100013
# 4 2023-06-12 18:10:00              2023-06-15         100014

# %%
# checking datatype 
groceries.dtypes
# Out:
# Product_ID                         object
# Category                           object
# Item                               object
# Price_Dollars                     float64
# Inventory                           int64
# Last_Updated               datetime64[ns]
# Next_Scheduled_Shipment    datetime64[ns]
# Product_ID_Num                     object
# dtype: object

# %%
#Still 'Product_ID_Num' is Object. So, covert it into INT 
groceries['Product_ID_Num'].astype('int')
# Out:
# 0     100010
# 1     100011
# 2     100012
# 3     100013
# 4     100014
# 5     100015
# 6     100016
# 7     100017
# 8     100018
# 9     100019
# 10    100020
# 11    100021
# 12    100022
# 13    100023
# 14    100024
# 15    100025
# 16    100026
# 17    100027
# 18    100028
# 19    100029
# 20    100030
# 21    100031
# 22    100032
# 23    100033
# 24    100034
# Name: Product_ID_Num, dtype: int32

# %%
# checking datatype 
groceries.dtypes
# Out:
# Product_ID                         object
# Category                           object
# Item                               object
# Price_Dollars                     float64
# Inventory                           int64
# Last_Updated               datetime64[ns]
# Next_Scheduled_Shipment    datetime64[ns]
# Product_ID_Num                     object
# dtype: object

# %%
#Still 'Product_ID_Num' is Object. So, give it a dataframe and save it. 
groceries['Product_ID_Num'] = groceries['Product_ID_Num'].astype('int')

# %%
# checking datatype 
groceries.dtypes
# Out:
# Product_ID                         object
# Category                           object
# Item                               object
# Price_Dollars                     float64
# Inventory                           int64
# Last_Updated               datetime64[ns]
# Next_Scheduled_Shipment    datetime64[ns]
# Product_ID_Num                      int32
# dtype: object

# %%
groceries.head()
# Out:
#   Product_ID        Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce: Fruit                 Apple           1.50        349
# 1    P100011  Produce: Fruit                Banana           0.40        500
# 2    P100012  Produce: Fruit                Grapes           4.00        200
# 3    P100013  Produce: Fruit            Grapefruit           0.99         50
# 4    P100014  Produce: Fruit  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment  Product_ID_Num
# 0 2023-06-12 15:35:00              2023-06-15          100010
# 1 2023-06-12 18:30:00              2023-06-15          100011
# 2 2023-06-12 17:22:00              2023-06-15          100012
# 3 2023-06-12 16:29:00              2023-06-15          100013
# 4 2023-06-12 18:10:00              2023-06-15          100014

# %%
# splitting the column 'category'
groceries.Category.str.split(':').to_list()
# Out:
# [['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Fruit'],
#  ['Produce', ' Vegetable'],
#  ['Produce', ' Vegetable'],
#  ['Produce', ' Vegetable'],
#  ['Produce', ' Vegetable'],
#  ['Produce', ' Meat'],
#  ['Produce', ' Meat'],
#  ['Produce', ' Meat'],
#  ['Produce', ' Dairy'],
#  ['Produce', ' Dairy'],
#  ['Produce', ' Dairy'],
#  ['Produce', ' Dairy'],
#  ['Pantry', ' Snacks'],
#  ['Pantry', ' Snacks'],
#  ['Pantry', ' Snacks'],
#  ['Pantry', ' Snacks'],
#  ['Frozen', ' Frozen Snacks'],
#  ['Frozen', ' Frozen Snacks'],
#  ['Frozen', ' Frozen Fruit'],
#  ['Frozen', ' Frozen Fruit']]

# %%
pd.DataFrame(groceries.Category.str.split(':').to_list())
# Out:
#           0               1
# 0   Produce           Fruit
# 1   Produce           Fruit
# 2   Produce           Fruit
# 3   Produce           Fruit
# 4   Produce           Fruit
# 5   Produce           Fruit
# 6   Produce       Vegetable
# 7   Produce       Vegetable
# 8   Produce       Vegetable
# 9   Produce       Vegetable
# 10  Produce            Meat
# 11  Produce            Meat
# 12  Produce            Meat
# 13  Produce           Dairy
# 14  Produce           Dairy
# 15  Produce           Dairy
# 16  Produce           Dairy
# 17   Pantry          Snacks
# 18   Pantry          Snacks
# 19   Pantry          Snacks
# 20   Pantry          Snacks
# 21   Frozen   Frozen Snacks
# 22   Frozen   Frozen Snacks
# 23   Frozen    Frozen Fruit
# 24   Frozen    Frozen Fruit

# %%
groceries[['Category', 'Subcategory']] = pd.DataFrame(groceries.Category.str.split(':').to_list())

# %%
groceries.head()
# Out:
#   Product_ID Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce                 Apple           1.50        349
# 1    P100011  Produce                Banana           0.40        500
# 2    P100012  Produce                Grapes           4.00        200
# 3    P100013  Produce            Grapefruit           0.99         50
# 4    P100014  Produce  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment  Product_ID_Num Subcategory
# 0 2023-06-12 15:35:00              2023-06-15          100010       Fruit
# 1 2023-06-12 18:30:00              2023-06-15          100011       Fruit
# 2 2023-06-12 17:22:00              2023-06-15          100012       Fruit
# 3 2023-06-12 16:29:00              2023-06-15          100013       Fruit
# 4 2023-06-12 18:10:00              2023-06-15          100014       Fruit

# %%
# checking if 'Item' column contains organic or Organic
groceries ['organic'] = groceries.Item.str.contains('organic|Organic', regex = True)

# %%
or make organic lower in item column and then search
# groceries.Item.str.lower().str.contains('organic')

# %%
groceries.head()
# Out:
#   Product_ID Category                  Item  Price_Dollars  Inventory  \
# 0    P100010  Produce                 Apple           1.50        349
# 1    P100011  Produce                Banana           0.40        500
# 2    P100012  Produce                Grapes           4.00        200
# 3    P100013  Produce            Grapefruit           0.99         50
# 4    P100014  Produce  Organic Strawberries           3.99        148
#
#          Last_Updated Next_Scheduled_Shipment  Product_ID_Num Subcategory  \
# 0 2023-06-12 15:35:00              2023-06-15          100010       Fruit
# 1 2023-06-12 18:30:00              2023-06-15          100011       Fruit
# 2 2023-06-12 17:22:00              2023-06-15          100012       Fruit
# 3 2023-06-12 16:29:00              2023-06-15          100013       Fruit
# 4 2023-06-12 18:10:00              2023-06-15          100014       Fruit
#
#    organic
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True

# %%
# reorganize or reorder the columns

groceries[['Product_ID', 'Product_ID_Num', 'Category', 'Subcategory', 'Item', 'organic', 'Price_Dollars', 'Inventory', 'Last_Updated', 'Next_Scheduled_Shipment']]
# Out:
#    Product_ID  Product_ID_Num Category     Subcategory                   Item  \
# 0     P100010          100010  Produce           Fruit                  Apple
# 1     P100011          100011  Produce           Fruit                 Banana
# 2     P100012          100012  Produce           Fruit                 Grapes
# 3     P100013          100013  Produce           Fruit             Grapefruit
# 4     P100014          100014  Produce           Fruit   Organic Strawberries
# 5     P100015          100015  Produce           Fruit             Watermelon
# 6     P100016          100016  Produce       Vegetable                Cabbage
# 7     P100017          100017  Produce       Vegetable                Carrots
# 8     P100018          100018  Produce       Vegetable                 Celery
# 9     P100019          100019  Produce       Vegetable               Cucumber
# 10    P100020          100020  Produce            Meat                   Beef
# ...
