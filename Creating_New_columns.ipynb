# %%
#Create Columns From Numeric Data

# %%
#Read data into Python
#Check the data type of each column
#Create a numeric column using arithmetic
#Create a numeric column using conditional logic

# %%
# Create a “Total Spend” column that includes both the pen cost and shipping cost for each sale
# Create a “Free Shipping” column that says yes if the sale included free shipping, and no otherwise

# %%
import pandas as pd
pen_sales = pd.read_excel('Pen Sales Data.xlsx')
pen_sales.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...

# %%
pen_sales.dtypes
# Out:
# Customer                  int64
# Item                     object
# Pen Cost                float64
# Shipping Cost           float64
# Purchase Date    datetime64[ns]
# Delivery Date    datetime64[ns]
# Review                   object
# dtype: object

# %%
# Create a “Total Spend” column that includes both the pen cost and shipping cost for each sale
pen_sales['Total Spend'] = pen_sales['Pen Cost'] + pen_sales['Shipping Cost']
pen_sales.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend
# 0         8.98
# 1        12.99
# 2        11.94
# 3         8.98
# 4        14.98

# %%
# Create a “Free Shipping” column that says yes if the sale included free shipping, and no otherwise

import numpy as np
pen_sales['Free Shipping'] = np.where(pen_sales['Shipping Cost'] == 0, 'free shipping', 'no')
pen_sales.head(60)
# Out:
#     Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0       5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1       5202               Sharpies     12.99           0.00    2023-05-01
# 2       5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3       5204               Gel Pens      5.99           2.99    2023-05-01
# 4       5205        Rollerball Pens     12.99           1.99    2023-05-01
# 5       5206      Gel Pens (Pastel)     14.99           1.99    2023-05-01
# 6       5207        Rollerball Pens     12.99           1.99    2023-05-01
# 7       5208        Rollerball Pens     12.99           1.99    2023-05-01
# 8       5209               Gel Pens      5.99           2.99    2023-05-01
# 9       5210      Gel Pens (Pastel)     14.99           4.99    2023-05-01
# 10      5211  Ballpoint Pens (Bold)      6.95           0.00    2023-05-01
# 11      5212  Ballpoint Pens (Bold)      6.95           2.99    2023-05-01
# 12      5213               Sharpies     12.99           1.99    2023-05-01
# 13      5214        Rollerball Pens     12.99           1.99    2023-05-01
# 14      5215         Ballpoint Pens      5.99           1.99    2023-05-01
# 15      5216               Gel Pens      5.99           0.00    2023-05-02
# 16      5217               Sharpies     12.99           2.99    2023-05-02
# 17      5218      Gel Pens (Pastel)     14.99           4.99    2023-05-02
# 18      5219         Ballpoint Pens      5.99           0.00    2023-05-02
# 19      5220               Gel Pens      5.99           0.00    2023-05-02
# 20      5221               Sharpies     12.99           1.99    2023-05-02
# 21      5222         Ballpoint Pens      5.99           1.99    2023-05-02
# 22      5223  Ballpoint Pens (Bold)      6.95           0.00    2023-05-02
# 23      5224               Sharpies     12.99           2.99    2023-05-02
# 24      5225  Ballpoint Pens (Bold)      6.95           2.99    2023-05-02
#
#    Delivery Date                                             Review  \
# 0     2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1     2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2     2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3     2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4     2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
# 5     2023-05-04  SmoothOperatorPen|This gel pen writes smoothly...
# 6     2023-05-03  InkStainedFingers|This pen is prone to leaking...
# 7     2023-05-07  BoldInkWriter|Unfortunately, this pen has a te...
# 8     2023-05-06  PenmanshipPro|The gel pen has a comfortable gr...
# 9     2023-05-02  GelPenGuru|This retractable gel pen has a fine...
# 10    2023-05-04  FinePointFan|Be careful with this pen, as it h...
# 11    2023-05-07  SignatureStylePen|The retractable ballpoint pe...
# 12    2023-05-03                               BoldAndBeautifulPen|
# 13    2023-05-07  RollerballRider|The ink in this pen has a tend...
# 14    2023-05-03  BallpointBandit|This ballpoint pen has a sleek...
# 15    2023-05-04  TwistAndWriteUser|The ink in this pen can some...
# 16    2023-05-04                                   ThePenWhisperer|
# 17    2023-05-03  InkFlowFollower|I was disappointed to find tha...
# 18    2023-05-07  ThePenAndInkLady|This ballpoint pen has a comf...
# 19    2023-05-07  WritingInstrumentsFan|This pen is great for wr...
# 20    2023-05-05  PenPrecisionPro|The retractable Sharpie marker...
# 21    2023-05-05  InkCollector|The ballpoint pen is lightweight ...
# 22    2023-05-06                             PenToPaperPersonality|
# 23    2023-05-06  SmoothWritingScribe|This fine point Sharpie ma...
# 24    2023-05-07  ThePenmanshipPundit|This pen writes smoothly a...
#
#     Total Spend  Free Shipping
# 0          8.98             no
# 1         12.99  free shipping
# 2         11.94             no
# 3          8.98             no
# 4         14.98             no
# 5         16.98             no
# 6         14.98             no
# 7         14.98             no
# 8          8.98             no
# 9         19.98             no
# 10         6.95  free shipping
# 11         9.94             no
# 12        14.98             no
# 13        14.98             no
# 14         7.98             no
# 15         5.99  free shipping
# 16        15.98             no
# 17        19.98             no
# 18         5.99  free shipping
# 19         5.99  free shipping
# 20        14.98             no
# 21         7.98             no
# 22         6.95  free shipping
# 23        15.98             no
# 24         9.94             no

# %%
pen_sales['Free Shipping'].value_counts()
# Out:
# Free Shipping
# no               19
# free shipping     6
# Name: count, dtype: int64

# %%
# Create Columns From DateTime Data

# %%
# Calculate the difference between two datetime columns and save it as a new column
# Take the average of a column

# %%
# Calculate the number of days between the purchase and delivery date for each sale
# Save it as a new column called “Delivery Time”
# What were the average days from purchase to delivery?

# %%
pen_sales.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend  Free Shipping
# 0         8.98             no
# 1        12.99  free shipping
# 2        11.94             no
# 3         8.98             no
# 4        14.98             no

# %%
# Calculate the number of days between the purchase and delivery date for each sale
# Save it as a new column called “Delivery Time”

pen_sales['Delivery Time'] = pen_sales['Delivery Date'] - pen_sales['Purchase Date']
pen_sales.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend  Free Shipping Delivery Time
# 0         8.98             no        2 days
# 1        12.99  free shipping        3 days
# 2        11.94             no        1 days
# 3         8.98             no        3 days
# 4        14.98             no        2 days

# %%
# What were the average days from purchase to delivery?
pen_sales['AVG_Delivery_Time'] = pen_sales['Delivery Time'].mean()
pen_sales.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend  Free Shipping Delivery Time AVG_Delivery_Time
# 0         8.98             no        2 days   3 days 05:45:36
# 1        12.99  free shipping        3 days   3 days 05:45:36
# 2        11.94             no        1 days   3 days 05:45:36
# 3         8.98             no        3 days   3 days 05:45:36
# 4        14.98             no        2 days   3 days 05:45:36

# %%
# Create Columns From Text Data

# %%
# Split one column into multiple columns
# Create a Boolean column (True / False) to show whether a text field contains particular words

# %%
# Split the reviews on the “|” character to create two new columns: “User Name” and “Review Text”
# Create a “Leak or Spill” column that flags the reviews that mention either “leak” or “spill”

# %%
pen_sales.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend  Free Shipping Delivery Time AVG_Delivery_Time
# 0         8.98             no        2 days   3 days 05:45:36
# 1        12.99  free shipping        3 days   3 days 05:45:36
# 2        11.94             no        1 days   3 days 05:45:36
# 3         8.98             no        3 days   3 days 05:45:36
# 4        14.98             no        2 days   3 days 05:45:36

# %%
# Split the reviews on the “|” character to create two new columns: “User Name” and “Review Text”
pen_sales.Review.str.split('|').to_list()
# Out:
# [['DoodleWithMe',
#   "I love the way this pen writes, but unfortunately it has a tendency to leak if left unused for too long. It's important to keep it capped when not in use."],
#  ['ScribbleMaster',
#   "The classic Sharpie marker has a bold, permanent ink that works on almost any surface. It's perfect for labeling, drawing, or writing in a variety of settings."],
#  ['PenPalForever',
#   'The retractable ballpoint pen has a durable, metal clip and a sturdy design. It writes with a consistent flow and is a reliable choice for everyday use.'],
#  ['TheWriteWay',
#   "This gel pen has a comfortable grip and writes with vibrant, consistent ink. It's perfect for taking notes or writing in a journal."],
#  ['PenAndPaperPerson',
#   "The rollerball pen has a smooth, fluid feel and creates bold, expressive lines. It's a great option for artists and writers who want to add personality to their work."],
#  ['SmoothOperatorPen',
#   "This gel pen writes smoothly with a bold, vibrant ink that stands out on paper. It's perfect for adding a pop of color to notes or artwork."],
#  ['InkStainedFingers',
#   'This pen is prone to leaking and can create a mess if not handled carefully. It writes well, but may not be the best option for those on-the-go.'],
#  ['BoldInkWriter',
#   'Unfortunately, this pen has a tendency to spill ink if jostled or dropped. It writes smoothly, but may not be the most practical choice for everyday use.'],
#  ['PenmanshipPro',
#   'The gel pen has a comfortable grip and writes with a consistent flow. The ink dries quickly and is smudge-proof, making it a great choice for left-handed writers.'],
#  ['GelPenGuru',
#   'This retractable gel pen has a fine point that allows for precise writing and drawing. The ink is water-resistant and fade-proof, ensuring long-lasting results.'],
#  ['FinePointFan',
#   'Be careful with this pen, as it has been known to leak if not stored upright. That being said, it writes with a bold ink that stands out on paper.'],
#  ['SignatureStylePen',
#   'The retractable ballpoint pen is convenient and easy to use. It writes cleanly and is a good choice for those who prefer a no-fuss writing instrument.'],
#  ['BoldAndBeautifulPen', ''],
#  ['RollerballRider',
#   "The ink in this pen has a tendency to leak out and create smudges on paper. It's a shame, because the pen itself is comfortable to hold and writes well."],
#  ['BallpointBandit',
#   "This ballpoint pen has a sleek design and writes smoothly with a consistent flow. It's a great option for everyday use and is available in a variety of colors."],
#  ['TwistAndWriteUser',
#   'The ink in this pen can sometimes leak out of the tip, creating a mess on paper. However, the pen is comfortable to hold and writes with a smooth flow.'],
#  ['ThePenWhisperer', ''],
#  ['InkFlowFollower',
#   'I was disappointed to find that this pen leaked after only a few uses. The ink is nice, but the potential for spills makes it difficult to recommend.'],
#  ['ThePenAndInkLady',
#   "This ballpoint pen has a comfortable grip and a medium point that creates clear, easy-to-read lines. It's a great option for writing notes or letters."],
#  ['WritingInstrumentsFan',
#   "This pen is great for writing, but it's not very travel-friendly as it has a tendency to spill ink in transit. It's best to use it in a stationary setting."],
#  ['PenPrecisionPro',
#   'The retractable Sharpie marker is convenient and easy to use. It has a durable tip and writes with a consistent flow.'],
#  ['InkCollector',
#   'The ballpoint pen is lightweight and comfortable to hold. It writes smoothly and has a medium point that creates a clear, legible line.'],
#  ['PenToPaperPersonality', ''],
#  ['SmoothWritingScribe',
#   'This fine point Sharpie marker has a precise tip that allows for detailed work. The ink dries quickly and is resistant to water and fading.'],
#  ['ThePenmanshipPundit',
#   'This pen writes smoothly and delivers a crisp line. The ink dries quickly and is smudge-proof, making it a great choice for left-handed writers.']]

# %%
pd.DataFrame(pen_sales.Review.str.split('|').to_list())
# Out:
#                         0                                                  1
# 0            DoodleWithMe  I love the way this pen writes, but unfortunat...
# 1          ScribbleMaster  The classic Sharpie marker has a bold, permane...
# 2           PenPalForever  The retractable ballpoint pen has a durable, m...
# 3             TheWriteWay  This gel pen has a comfortable grip and writes...
# 4       PenAndPaperPerson  The rollerball pen has a smooth, fluid feel an...
# 5       SmoothOperatorPen  This gel pen writes smoothly with a bold, vibr...
# 6       InkStainedFingers  This pen is prone to leaking and can create a ...
# 7           BoldInkWriter  Unfortunately, this pen has a tendency to spil...
# 8           PenmanshipPro  The gel pen has a comfortable grip and writes ...
# 9              GelPenGuru  This retractable gel pen has a fine point that...
# 10           FinePointFan  Be careful with this pen, as it has been known...
# 11      SignatureStylePen  The retractable ballpoint pen is convenient an...
# 12    BoldAndBeautifulPen
# 13        RollerballRider  The ink in this pen has a tendency to leak out...
# 14        BallpointBandit  This ballpoint pen has a sleek design and writ...
# 15      TwistAndWriteUser  The ink in this pen can sometimes leak out of ...
# 16        ThePenWhisperer
# 17        InkFlowFollower  I was disappointed to find that this pen leake...
# 18       ThePenAndInkLady  This ballpoint pen has a comfortable grip and ...
# 19  WritingInstrumentsFan  This pen is great for writing, but it's not ve...
# 20        PenPrecisionPro  The retractable Sharpie marker is convenient a...
# 21           InkCollector  The ballpoint pen is lightweight and comfortab...
# 22  PenToPaperPersonality
# 23    SmoothWritingScribe  This fine point Sharpie marker has a precise t...
# 24    ThePenmanshipPundit  This pen writes smoothly and delivers a crisp ...

# %%
pen_sales[['User Name', 'Review Text']] = pd.DataFrame(pen_sales.Review.str.split('|').to_list())

# %%
pen_sales.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend  Free Shipping Delivery Time AVG_Delivery_Time  \
# 0         8.98             no        2 days   3 days 05:45:36
# 1        12.99  free shipping        3 days   3 days 05:45:36
# 2        11.94             no        1 days   3 days 05:45:36
# 3         8.98             no        3 days   3 days 05:45:36
# 4        14.98             no        2 days   3 days 05:45:36
#
#            User Name                                        Review Text
# 0       DoodleWithMe  I love the way this pen writes, but unfortunat...
# 1     ScribbleMaster  The classic Sharpie marker has a bold, permane...
# 2      PenPalForever  The retractable ballpoint pen has a durable, m...
# 3        TheWriteWay  This gel pen has a comfortable grip and writes...
# 4  PenAndPaperPerson  The rollerball pen has a smooth, fluid feel an...

# %%
# Create a “Leak or Spill” column that flags the reviews that mention either “leak” or “spill”

pen_sales['Leak or Spill'] = pen_sales.Review.str.contains('leak|spill', regex = True)
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend  Free Shipping Delivery Time AVG_Delivery_Time  \
# 0         8.98             no        2 days   3 days 05:45:36
# 1        12.99  free shipping        3 days   3 days 05:45:36
# 2        11.94             no        1 days   3 days 05:45:36
# 3         8.98             no        3 days   3 days 05:45:36
# 4        14.98             no        2 days   3 days 05:45:36
#
#            User Name                                        Review Text  \
# 0       DoodleWithMe  I love the way this pen writes, but unfortunat...
# 1     ScribbleMaster  The classic Sharpie marker has a bold, permane...
# 2      PenPalForever  The retractable ballpoint pen has a durable, m...
# 3        TheWriteWay  This gel pen has a comfortable grip and writes...
# 4  PenAndPaperPerson  The rollerball pen has a smooth, fluid feel an...
#
#    leak or spill  Leak or Spill
# 0           True           True
# 1          False          False
# 2          False          False
# 3          False          False
# 4          False          False

# %%
pen_sales.head()
# Out:
#    Customer                   Item  Pen Cost  Shipping Cost Purchase Date  \
# 0      5201         Ballpoint Pens      5.99           2.99    2023-05-01
# 1      5202               Sharpies     12.99           0.00    2023-05-01
# 2      5203  Ballpoint Pens (Bold)      6.95           4.99    2023-05-01
# 3      5204               Gel Pens      5.99           2.99    2023-05-01
# 4      5205        Rollerball Pens     12.99           1.99    2023-05-01
#
#   Delivery Date                                             Review  \
# 0    2023-05-03  DoodleWithMe|I love the way this pen writes, b...
# 1    2023-05-04  ScribbleMaster|The classic Sharpie marker has ...
# 2    2023-05-02  PenPalForever|The retractable ballpoint pen ha...
# 3    2023-05-04  TheWriteWay|This gel pen has a comfortable gri...
# 4    2023-05-03  PenAndPaperPerson|The rollerball pen has a smo...
#
#    Total Spend  Free Shipping Delivery Time AVG_Delivery_Time  \
# 0         8.98             no        2 days   3 days 05:45:36
# 1        12.99  free shipping        3 days   3 days 05:45:36
# 2        11.94             no        1 days   3 days 05:45:36
# 3         8.98             no        3 days   3 days 05:45:36
# 4        14.98             no        2 days   3 days 05:45:36
#
#            User Name                                        Review Text  \
# 0       DoodleWithMe  I love the way this pen writes, but unfortunat...
# 1     ScribbleMaster  The classic Sharpie marker has a bold, permane...
# 2      PenPalForever  The retractable ballpoint pen has a durable, m...
# 3        TheWriteWay  This gel pen has a comfortable grip and writes...
# 4  PenAndPaperPerson  The rollerball pen has a smooth, fluid feel an...
#
#    Leak or Spill
# 0           True
# 1          False
# 2          False
# 3          False
# 4          False
